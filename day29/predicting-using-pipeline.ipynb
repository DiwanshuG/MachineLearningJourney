# %%
import joblib

# %%
pipe = joblib.load("titanic_pipeline.joblib")

# %%
import pandas as pd

# %%
user_input = pd.DataFrame(
    [[2, 'male' , 31 , 0 , 0 , 10.5 , 'S']],
    columns = [ 'Pclass' , 'Sex' , 'Age' , 'SibSp' , 'Parch' , 'Fare' , 'Embarked'])

# %%
prediction = pipe.predict(user_input)

# %%
print(prediction)
# Out:
# [0]
