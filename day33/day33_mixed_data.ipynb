# %% [markdown]
# ## Mixed data

# %% [markdown]
# #### – Titanic `Cabin` Column
#
# The `Cabin` feature in the Titanic dataset is a **mixed variable** because a single column contains multiple types of information:
# - Categorical
# - Numerical
# - Missing-value signal
#
# ---
#
# ## Example Values
# ```text
# C85
# E46
# G6
# B28
# NaN

# %%
# Correct Feature Engineering Approach

# %% [markdown]
# 1. Extract Deck (Categorical Feature)
# ```python
# df['Deck'] = df['Cabin'].str[0]
# ```

# %% [markdown]
# 2. Extract Cabin Number
# ```python
# df['Cabin_Num'] = df['Cabin'].str.extract('(\d+)').astype(float)
# ```

# %%
# ColumnTransformer Implementation

# %% [raw]
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder, StandardScaler
#
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('num', StandardScaler(), ['Cabin_Num']),
#         ('cat', OneHotEncoder(handle_unknown='ignore'), ['Deck'])
#     ]
# )
